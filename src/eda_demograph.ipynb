# %% [markdown]
# # Explore here

# %%
import pandas as pd 

df= pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv')
pd.set_option('display.max_columns', None)
df.tail(20)
#'10-19 y/o % of total pop', '20-29 y/o % of total pop', '0-9 y/o % of total pop', '30-39 y/o % of total pop', '40-49 y/o % of total pop', '50-59 y/o % of total pop', '60-69 y/o % of total pop', '70-79 y/o % of total pop', '80+ y/o % of total pop', '%White-alone', '%Black-alone', '% NA/AI-alone', '% Asian-alone',
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 3120  56007    14971   1917               12.804756    1830
# 3121  56009    13640   1811               13.277126    1857
# 3122  56011     7450   1036               13.906040     904
# 3123  56013    39531   5585               14.128153    5452
# 3124  56015    13376   1462               10.930024    1636
# 3125  56017     4555    499               10.954995     548
# 3126  56019     8460    954               11.276596    1042
# 3127  56021    98976  12734               12.865745   12490
# 3128  56023    19434   2734               14.068128    2818
# 3129  56025    79115  10543               13.326171   10258
# 3130  56027     2388    249               10.427136     217
# 3131  56029    29324   3290               11.219479    3478
# 3132  56031     8566    947               11.055335     931
# 3133  56033    30233   3444               11.391526    3768
# 3134  56035     9813   1157               11.790482    1235
# ...

# %%
df.shape
# Out:
# (3140, 108)

# %%
if df.duplicated().sum():
    df = df.drop_duplicates()
print(df.shape)
df.head(3)
# Out:
# (3140, 108)
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
#
#    30-39 y/o % of total pop  40-49  40-49 y/o % of total pop  50-59  \
# 0                 12.749771   7582                 13.636445   7738
# 1                 11.564429  27338                 12.539102  29986
# 2                 12.865239   3074                 12.354809   3278
#
#    50-59 y/o % of total pop  60-69  60-69 y/o % of total pop  70-79  \
# 0                 13.917016   5826                 10.478229   4050
# ...
